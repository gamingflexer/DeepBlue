# %%
pip install spacy==2.3.5
# Out:
# ...
#      |████████████████████████████████| 5.8 MB 7.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached plac-1.1.3-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached thinc-7.4.5-cp39-cp39-macosx_11_0_arm64.whl
# ...
#   Using cached srsly-1.0.5-cp39-cp39-macosx_11_0_arm64.whl
# ...
#   Using cached catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# ...
#   Created wheel for spacy: filename=spacy-2.3.5-cp39-cp39-macosx_11_0_arm64.whl size=9915855 sha256=b44f548b1540ac02f0c95e6d5fcd3be58b60afcb1b727151f897f2e05408753e
#   Stored in directory: /Users/cosmos/Library/Caches/pip/wheels/10/32/a9/0909f122be8d2677ff83c55f5287511d7c73c1a1db3434485c
# Successfully built spacy
# ...
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
#     Uninstalling srsly-2.4.2:
#       Successfully uninstalled srsly-2.4.2
#   Attempting uninstall: catalogue
# ...

# %%
import spacy
model_path = '/Users/cosmos/Desktop/DeepBlue/BACKEND/ML/Spacy - Model/model'

# %%
from tika import parser # pip install tika

raw = parser.from_file('/Users/cosmos/Desktop/DeepBlue/Dataset-Scraping/Resumes/type_1.pdf')
print(raw['content'])
# Out:
# Phil Roberts, HVAC
# Technician
# O R L ANDO , FL ,  3 2 8 0 4 ,  UNITE D STATE S · 8 9 0 -5 5 5 -0 4 0 1
#
# PROFILE
#
# Professional HVAC Technician with 6 years of experience in commercial and residential
# settings.
#
# EMPLOYMENT HISTORY
#
# HVAC Technician, Central Florida Heating & Air
# Jul 2013 – Present, Orlando, FL
#
# Central Florida Heating & Air provides heating, ventilation, and air conditioning services to
# residential and commercial customers. As an HVAC Technician, my core responsibilities include:
#
# Visiting work sites to determine the client's requirements
# Installing, maintaining, and repairing HVAC equipment, including ordering the necessary
# parts, when needed
# Making rounds of equipment to ensure all auxiliary components are operable and in good
# condition
# Tracking all work orders in the internal system, including entering materials used and hours
# worked
# Selling ongoing maintenance contracts to customers
#
# HVAC Technician, Billy's Heating & Air
# ...

# %%
print("Loading from", model_path)
model = spacy.load(model_path)
resume = model(raw['content'])
print("Entities", [(ent.text, ent.label_) for ent in resume.ents])
# Out:
# Loading from /Users/cosmos/Desktop/DeepBlue/BACKEND/ML/Spacy - Model/model
# Entities [('Florida Technical College', 'CollegeName')]
