# %%
import pandas as pd

# %%
data=pd.read_csv("resumes_indeed_com-job_sample.csv")

# %%
data.describe()
# Out:
#                                  Uniq Id            Crawl Timestamp  \
# count                                 10                         10
# unique                                10                         10
# top     7795cdc183ab88aaffec73a5d99a1b82  2019-02-20 06:57:56 +0000
# freq                                   1                          1
#
#                   Resume Title       Location  \
# count                       10             10
# unique                      10              9
# top     Safety Engineer Intern  Worcester, MA
# freq                         1              2
#
#                                              Introduction  \
# count                                                   5
# unique                                                  5
# top     Experienced, dependable and motivated IT Techn...
# freq                                                    1
#
#                                           Work Experience  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Uniq Id                 10 non-null     object
#  1   Crawl Timestamp         10 non-null     object
#  2   Resume Title            10 non-null     object
#  3   Location                10 non-null     object
#  4   Introduction            5 non-null      object
#  5   Work Experience         10 non-null     object
#  6   Education               9 non-null      object
#  7   Skills                  5 non-null      object
#  8   Additional Information  7 non-null      object
# dtypes: object(9)
# memory usage: 848.0+ bytes

# %%
data.head(10)
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  3ddb29e616f31947053b257f327969d7  2019-02-20 08:47:25 +0000
# 1  9138476c76bcbbefadedd4862966c3d2  2019-02-20 07:47:48 +0000
# 2  cd1cafa706f917a627982bf47291b888  2019-02-20 07:37:41 +0000
# 3  53aea69598c6c1084e4bce89f0494bc3  2019-02-20 08:20:06 +0000
# 4  90f8f99d66ebc6c09fceee37aff14bc1  2019-02-20 08:35:33 +0000
# 5  fb1c760fd5311dad01e950f3062a9296  2019-02-20 06:57:56 +0000
# 6  7795cdc183ab88aaffec73a5d99a1b82  2019-02-20 07:27:41 +0000
# 7  e219a144eca8463f5d70fdec9426466f  2019-02-20 08:15:39 +0000
# 8  c7c409fe9652e1eae9ecb05cce05426e  2019-02-20 08:59:32 +0000
# 9  7f562eaaa992790efe423a197bfd0ffa  2019-02-20 07:31:38 +0000
#
#                                       Resume Title         Location  \
# 0                                    Sales Manager   New London, NH
# 1                          Implementation Engineer    Worcester, MA
# ...

# %%
data.drop("Crawl Timestamp",axis=1)
# Out:
#                             Uniq Id  \
# 0  3ddb29e616f31947053b257f327969d7
# 1  9138476c76bcbbefadedd4862966c3d2
# 2  cd1cafa706f917a627982bf47291b888
# 3  53aea69598c6c1084e4bce89f0494bc3
# 4  90f8f99d66ebc6c09fceee37aff14bc1
# 5  fb1c760fd5311dad01e950f3062a9296
# 6  7795cdc183ab88aaffec73a5d99a1b82
# 7  e219a144eca8463f5d70fdec9426466f
# 8  c7c409fe9652e1eae9ecb05cce05426e
# 9  7f562eaaa992790efe423a197bfd0ffa
#
#                                       Resume Title         Location  \
# 0                                    Sales Manager   New London, NH
# 1                          Implementation Engineer    Worcester, MA
# 2  Education Information Dissemination Coordinator      Bristol, NH
# 3                    Engineering Department Intern    Billerica, MA
# 4                    Pack and Ship/SORT Technician    Worcester, MA
# 5                                 BDC Data Analyst  Springfield, MA
# 6                           Safety Engineer Intern       Boston, MA
# ...

# %%
data.drop("Uniq Id",axis=1)
# Out:
#              Crawl Timestamp                                     Resume Title  \
# 0  2019-02-20 08:47:25 +0000                                    Sales Manager
# 1  2019-02-20 07:47:48 +0000                          Implementation Engineer
# 2  2019-02-20 07:37:41 +0000  Education Information Dissemination Coordinator
# 3  2019-02-20 08:20:06 +0000                    Engineering Department Intern
# 4  2019-02-20 08:35:33 +0000                    Pack and Ship/SORT Technician
# 5  2019-02-20 06:57:56 +0000                                 BDC Data Analyst
# 6  2019-02-20 07:27:41 +0000                           Safety Engineer Intern
# 7  2019-02-20 08:15:39 +0000                           Classified Ads Manager
# 8  2019-02-20 08:59:32 +0000                        ASSISTANT PROGRAM MANAGER
# 9  2019-02-20 07:31:38 +0000                       Technical Customer Service
#
#           Location                                       Introduction  \
# ...
